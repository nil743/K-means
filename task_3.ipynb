# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets
import seaborn as sns

# %%
iris = datasets.load_iris()
iris_df = pd.DataFrame(iris.data, columns = iris.feature_names)
iris_df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
x=iris_df.values
from sklearn.cluster import KMeans
wcss = []
x1 = x[:,0]
x2 = x[:,1]
plt.plot() 
plt.xlim([2, 10]) 
plt.ylim([2, 10]) 
plt.title('Dataset') 
plt.scatter(x1, x2) 
plt.show() 
for i in range(1,9):
    kmeans= KMeans(n_clusters=i).fit(x)
    wcss.append(kmeans.inertia_)
    x1 = kmeans.cluster_centers_[:,0]
    x2 = kmeans.cluster_centers_[:,1]
    plt.plot() 
    plt.xlim([2, 10]) 
    plt.ylim([2, 10]) 
    plt.title('cluster centers') 
    plt.scatter(x1, x2) 
    plt.show()

# %% [markdown]
# # The elbow method

# %%
plt.plot(range(1,9), wcss)
plt.title('The elbow method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()
print(wcss)
# Out:
# [681.3706, 152.34795176035792, 78.85144142614601, 57.25600931571815, 46.44618205128205, 39.03998724608725, 34.420191786283894, 29.990426406926414]

# %% [markdown]
# # Pairplot

# %%
sns.pairplot(iris_df)
